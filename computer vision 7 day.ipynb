# %% [markdown]
# # 영상분활

# %%
import cv2
import numpy as np

# %% [markdown]
# * 색상 범위 지정에 의한 영상 분활

# %%
src = cv2.imread('./data/hand.jpg')
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)

# %% [markdown]
# lowerb = (h, s, v)
#
# upperb = (h, s, v)

# %%
lowerb = (0, 40,0)
upperb = (30, 170,255)

dst = cv2.inRange(hsv, lowerb, upperb) #해당 구간이 255로 하얗게 나옴.

# %%
def mouse_callback(event, x, y, flags, param):
    global hsv
    if event == cv.EVENT_LBUTTONDOWN:
        print(img_color[y, x])
        color = img_color[y, x]

        one_pixel = np.uint8([[color]])
        hsv = cv.cvtColor(one_pixel, cv.COLOR_BGR2HSV)
        hsv = hsv[0][0]

# %%
import pyautogui
from PIL import Image
from PIL import ImageGrab
import time
image = Image.open("./data/hand.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x1FFAE701610>

# %%
time.sleep(3)
screen = ImageGrab.grab() # 화면 캡쳐 
print(screen.getpixel(pyautogui.position()))#현재의 마우스 위치의 색상 출력.
# Out:
# (145, 97, 75)

# %%
cv2.imshow('src',src)
cv2.imshow('dst',dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
#  ![color3.2.png](attachment:color3.2.png)

# %%
cv2.destroyAllWindows()

# %%
src = cv2.imread('./data/flower.jpg')
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)

# %%
lowerb = (100, 100,100)
upperb = (170, 255,255)

dst = cv2.inRange(hsv, lowerb, upperb)

# %%
cv2.imshow('src',src)
cv2.imshow('dst',dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./data/candies.png')
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
def onChange(x):
    global hsv
    h = cv2.getTrackbarPos('h', 'hsv') 
    s = cv2.getTrackbarPos('s', 'hsv') 
    v = cv2.getTrackbarPos('v', 'hsv')
    img[:] = (h, s, v)
    cv2.imshow('hsv', hsv)
img = cv2.imread('./data/flower.jpg')
cv2.imshow('hsv', hsv)
cv2.createTrackbar('h', 'hsv',0,255, onChange) 
cv2.createTrackbar('s', 'hsv', 0, 255, onChange) 
cv2.createTrackbar('v','hsv', 0, 255, onChange)

cv2.setTrackbarPos('h','hsv', 105)
cv2.setTrackbarPos('s','hsv', 200)
cv2.setTrackbarPos('v','hsv', 105)

cv2.waitKey() 
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
def onChange(pos):
    global src
    global hsv
    
    lh = cv2.getTrackbarPos('Lower Hue', 'src')
    uh = cv2.getTrackbarPos('Upper Hue', 'src')
    dst = cv2.inRange(src, (lh,100,0), (uh,255,255))
    
    cv2.imshow('dst', dst)

src = cv2.imread('./data/candies.png')
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
cv2.imshow('src', src)

cv2.createTrackbar('Lower Hue', 'src', 0, 255, onChange)
cv2.createTrackbar('Upper Hue', 'src', 0, 255, onChange)

cv2.setTrackbarPos('Lower Hue', 'src', 40)
cv2.setTrackbarPos('Upper Hue', 'src', 80)

cv2.waitKey() 
cv2.destroyAllWindows()

# %%
cv2.imshow('src', src)
cv2.waitKey() 
cv2.destroyAllWindows()
